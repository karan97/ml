# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\gupta\Desktop\Lectures\[DesireCourse.Net] Udemy - Complete Tensorflow 2 and Keras Deep Learning Bootcamp\1. Course Overview, Installs, and Setup\2.1 FINAL_TF2_FILES.zip\TF_2_Notebooks_and_Data\03-ANNs\california_housing_sklearn.csv')

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  SalePrice
# 0    -122.23      4.526
# 1    -122.22      3.585
# 2    -122.24      3.521
# 3    -122.25      3.413
# 4    -122.25      3.422

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# SalePrice     0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585558    1.000000   18.000000
# AveRooms    20640.0     5.429000     2.474173    0.846154    4.440716
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476744  1132.462122    3.000000  787.000000
# AveOccup    20640.0     3.070655    10.386050    0.692308    2.429741
# Latitude    20640.0    35.631861     2.135952   32.540000   33.930000
# Longitude   20640.0  -119.569704     2.003532 -124.350000 -121.800000
# SalePrice   20640.0     2.068558     1.153956    0.149990    1.196000
#
#                     50%          75%           max
# MedInc         3.534800     4.743250     15.000100
# HouseAge      29.000000    37.000000     52.000000
# AveRooms       5.229129     6.052381    141.909091
# AveBedrms      1.048780     1.099526     34.066667
# ...

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'SalePrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
# MedInc        20640 non-null float64
# HouseAge      20640 non-null float64
# AveRooms      20640 non-null float64
# AveBedrms     20640 non-null float64
# Population    20640 non-null float64
# AveOccup      20640 non-null float64
# Latitude      20640 non-null float64
# Longitude     20640 non-null float64
# SalePrice     20640 non-null float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['SalePrice'])

# %%
sns.pairplot(data=df)

# %%
sns.countplot(df['AveBedrms'],data=df)

# %%
df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# SalePrice   0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude  SalePrice
# MedInc     -0.079809  -0.015176   0.688075
# HouseAge    0.011173  -0.108197   0.105623
# AveRooms    0.106389  -0.027540   0.151948
# AveBedrms   0.069721   0.013344  -0.046701
# ...

# %%
sns.scatterplot(y='Population',x='SalePrice',data=df)

# %%
sns.heatmap(df.corr(),linewidth=5,annot=True)

# %%
sns.jointplot(x='MedInc',y='SalePrice',data=df)

# %%
sns.jointplot(x='HouseAge',y='SalePrice',data=df)

# %%
sns.jointplot(y='AveRooms',x='SalePrice',data=df)

# %%
plt.figure(figsize=(10,6))
sns.jointplot(y='AveBedrms',x='SalePrice',data=df)

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'SalePrice'],
#       dtype='object')

# %%
df['AveBedrms'].mean()
# Out:
# 1.0966751496062053

# %%
df['AveRooms'].mean()
# Out:
# 5.428999742190365

# %%
sns.jointplot(y='Population',x='SalePrice',data=df)

# %%
df['Population'].mean()
# Out:
# 1425.4767441860465

# %%
sns.scatterplot(x='SalePrice',y='Latitude',data=df)

# %%
sns.scatterplot(x='SalePrice',y='Longitude',data=df)

# %%
sns.scatterplot(x='Longitude',y='Latitude',data=df,hue='SalePrice')

# %%
df.sort_values('SalePrice',ascending=False).head(5)
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 10667  10.1275      27.0  7.493421   1.039474       772.0  2.539474     33.55
# 16916   7.0422      52.0  7.045455   1.090909       967.0  2.585561     37.57
# 16946   6.1349      33.0  6.893417   0.978056       827.0  2.592476     37.55
# 8877    8.0257      48.0  7.781046   1.127451       859.0  2.807190     34.04
# 8878   15.0001      52.0  8.000000   0.997333      1143.0  3.048000     34.04
#
#        Longitude  SalePrice
# 10667    -117.88    5.00001
# 16916    -122.34    5.00001
# 16946    -122.33    5.00001
# 8877     -118.49    5.00001
# 8878     -118.50    5.00001

# %%
df['SalePrice'].unique()
# Out:
# array([4.526, 3.585, 3.521, ..., 4.258, 2.007, 0.47 ])

# %%
def price_ext(price):
    if df['Saleprice'] != 5.00001:
        return df[price]

# %%
df.groupby('MedInc').mean()['SalePrice'].plot()

# %%
sns.jointplot(y='MedInc',x='SalePrice',data=df)

# %%
X = credit[['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']]

# %%
X = df[['MedInc','AveRooms']].values
y = df['SalePrice'].values

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Train on 13828 samples, validate on 6812 samples
# Epoch 1/400
# 13828/13828 [==============================] - 1s 40us/sample - loss: 2.6901 - val_loss: 0.9067
# Epoch 2/400
# 13828/13828 [==============================] - 0s 15us/sample - loss: 0.8050 - val_loss: 0.7239
# Epoch 3/400
# 13828/13828 [==============================] - 0s 15us/sample - loss: 0.6990 - val_loss: 0.6939
# Epoch 4/400
# 13828/13828 [==============================] - 0s 16us/sample - loss: 0.6884 - val_loss: 0.6898
# Epoch 5/400
# 13828/13828 [==============================] - 0s 17us/sample - loss: 0.6874 - val_loss: 0.6868
# Epoch 6/400
# 13828/13828 [==============================] - 0s 15us/sample - loss: 0.6824 - val_loss: 0.6834
# Epoch 7/400
# 13828/13828 [==============================] - 0s 15us/sample - loss: 0.6781 - val_loss: 0.6852
# Epoch 8/400
# 13828/13828 [==============================] - 0s 16us/sample - loss: 0.6758 - val_loss: 0.6793
# Epoch 9/400
# ...

# %%
pd.DataFrame(model.history.history).plot()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 0.7946583324751624

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 0.5576822471379141

# %%
df['SalePrice'].describe()
# Out:
# count    20640.000000
# mean         2.068558
# std          1.153956
# min          0.149990
# 25%          1.196000
# 50%          1.797000
# 75%          2.647250
# max          5.000010
# Name: SalePrice, dtype: float64

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.5375773557244719

# %%
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
singleh = df.drop('SalePrice',axis=1).iloc[0]

# %%
si = singleh.values.reshape(-1,8)
si
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#          322.        ,    2.55555556,   37.88      , -122.23      ]])

# %%
scaler.transform(si)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-e0f111fccb64> in <module>
# ----> 1 scaler.transform(si)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in transform(self, X)
#     387                         force_all_finite="allow-nan")
#     388
# --> 389         X *= self.scale_
#     390         X += self.min_
#     391         return X
#
# ValueError: operands could not be broadcast together with shapes (1,8) (2,) (1,8)
